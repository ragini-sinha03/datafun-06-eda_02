# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Load the dataset into a pandas DataFrame - adjust this process for your custom data
data = sns.load_dataset('healthexp')

# Inspect first rows of the DataFrame
print(data.head())


# Show plot
plt.show()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %% [markdown]
# EDA Analysis: Initial Data Inspetion

# %%
print(data.head(10))
print(data.shape)
print(data.dtypes)
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9
# 5  1971         Canada       313.391             72.8
# 6  1971        Germany       298.251             70.8
# 7  1971  Great Britain       134.172             71.9
# 8  1971          Japan       163.854             72.9
# 9  1971            USA       357.988             71.2
# (274, 4)
# Year                 int64
# Country             object
# Spending_USD       float64
# Life_Expectancy    float64
# dtype: object

# %% [markdown]
# Observation: I could get the type of data available in the data by using the above command.

# %% [markdown]
# EDA Analysis: Initial Descriptive Statistics

# %%
print(data.describe())
# Out:
#               Year  Spending_USD  Life_Expectancy
# count   274.000000    274.000000       274.000000
# mean   1996.992701   2789.338905        77.909489
# std      14.180933   2194.939785         3.276263
# min    1970.000000    123.993000        70.600000
# 25%    1985.250000   1038.357000        75.525000
# 50%    1998.000000   2295.578000        78.100000
# 75%    2009.000000   4055.610000        80.575000
# max    2020.000000  11859.179000        84.700000

# %% [markdown]
# Observation: It helps to understand the distribution, central tendency, and variability of data.

# %% [markdown]
# EDA Analysis: Initial Data Distribution for all numerical columns

# %%
# Inspect histograms for all numerical columns
data.hist()

# Show all plots
plt.show()

# %% [markdown]
# Observation: The visualizations are in the form of histogram.

# %% [markdown]
# EDA analysis: Rename Columns

# %%
#Check data transformations
print(data.head(10))
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9
# 5  1971         Canada       313.391             72.8
# 6  1971        Germany       298.251             70.8
# 7  1971  Great Britain       134.172             71.9
# 8  1971          Japan       163.854             72.9
# 9  1971            USA       357.988             71.2

# %% [markdown]
#  EDA Analysis: Line Plot of Spending Over Time by Country

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=data, x="Year", y="Spending_USD", hue="Country")
plt.title("Healthcare Spending Over Time by Country")
plt.xlabel("Year")
plt.ylabel("Spending in USD")
plt.legend(title='Country')
plt.show()

# %% [markdown]
# Observations: There is a continous and steep increase in healthcare expenditure in United States.The United Kingdom has the lowest among teh listed countries.  Moreover, USA spend more on healthcare than all other countries that is notable from 2000s onwards.

# %% [markdown]
#  EDA Analysis: Scatter Plot with Regression Line (Spending vs Life Expectancy)

# %%
plt.figure(figsize=(12, 6))
sns.lmplot(data=data, x="Spending_USD", y="Life_Expectancy", hue="Country", height=6, aspect=1.5)
plt.title("Healthcare Spending vs. Life Expectancy")
plt.xlabel("Spending in USD")
plt.ylabel("Life Expectancy")
plt.show()

# %% [markdown]
# Observation: It shows a relationship between healthcare spending in USD and life expentancy with each country. It shows a general trend that as healthcare spending increases, life expentancy also tends to increase. So, it is a positive correlation.

# %% [markdown]
# EDA Analysis: Facet Grid of Spending Over Time by Country

# %%
g = sns.FacetGrid(data, col="Country", col_wrap=3, height=4)
g.map(sns.lineplot, "Year", "Spending_USD")
g.add_legend()
plt.subplots_adjust(top=0.9)
g.fig.suptitle("Healthcare Spending Over Time by Country")
plt.show()

# %% [markdown]
# Observation: This shows countries spending money on their healthcare in decades.

# %% [markdown]
# EDA Analysis: To visualize the healthcare spending and life expectancy for different countries in swarm plot form.

# %%
plt.figure(figsize=(14, 8))
sns.swarmplot(x='Country', y='Spending_USD', data=data)
plt.title('Healthcare Spending by Country')
plt.xlabel('Country')
plt.ylabel('Healthcare Spending (USD)')
plt.show()

# %% [markdown]
# Observation: This plot displayed the distribution of healthcare spending across different countries with USA spending the highest amount on healthcare.

# %% [markdown]
# Observation: It visualizes the life expectancy over the years for different countries, with

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is a DataFrame containing the necessary columns: 'Year', 'Life_Expectancy', and 'Country'

# Swarm plot
plt.figure(figsize=(14, 5))
sns.swarmplot(data=data,
              x="Year",
              y="Life_Expectancy",
              hue="Country",   # Corrected to match the column name exactly
              dodge=True,      # Separate strips of points of different colors
              order=[1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020],  # Specified order of years
              palette="muted"  # Apply the muted color palette
             )

plt.title("Life Expectancy by Year and Country")
plt.show()

# %% [markdown]
# Observation: This code show visualization dealing with non-sequential years. I observed from this grapg that Japan has a good life expentancy beteen 1970 to 2020.

# %% [markdown]
# EDA Analysis: Changing columns name

# %%
#import pandas as pd

# Assuming 'data' is a DataFrame containing your data
#data = pd.read_csv("healthexp.csv")  # Replace "your_data_file.csv" with the actual file name or path

# Rename columns
data = data.rename(columns={"Spending_USD": "USD",
                            "Life_Expectancy": "Life",
                            # Add more columns as needed
                           })

# Display the DataFrame to verify the changes
print(data.head(10))  # Use head() to display the first few rows of the DataFrame
# Out:
#    Year        Country      USD  Life
# 0  1970        Germany  252.311  70.6
# 1  1970         France  192.143  72.2
# 2  1970  Great Britain  123.993  71.9
# 3  1970          Japan  150.437  72.0
# 4  1970            USA  326.961  70.9
# 5  1971         Canada  313.391  72.8
# 6  1971        Germany  298.251  70.8
# 7  1971  Great Britain  134.172  71.9
# 8  1971          Japan  163.854  72.9
# 9  1971            USA  357.988  71.2

# %% [markdown]
# Observation: Through this code, I could change the column titles.

# %% [markdown]
# EDA Analysis: Finding median

# %%
# Find the median for the 'Life_Expectancy' column
median_life_expectancy = data['Life_Expectancy'].median()

# Print the median value
print("Median Life Expectancy:", median_life_expectancy)
# Out:
# Median Life Expectancy: 78.1

# %% [markdown]
# EDA Analysis: Finding Mean

# %%
# Calculate the mean of the 'Life_Expectancy' column
mean_life_expectancy = data['Life_Expectancy'].mean()

# Print the mean value
print("Mean Life Expectancy:", mean_life_expectancy)
# Out:
# Mean Life Expectancy: 77.90948905109488

# %% [markdown]
# Observation: Through observation, I found that mean and median are bit close so, the distribution of life expectancies will be symmetric.

# %% [markdown]
# EDA Analysis:  To predicting the years for Great Britain to catch up with the USA in terms of life expectancy.

# %%
#data = pd.read_csv("healthexp.csv")

# filter data for Great Britain and USA
gb_data = data[data['Country'] == 'Great Britain']
usa_data = data[data['Country'] == 'USA']

# reshape data for scikit-learn
X_gb = gb_data['Year'].values.reshape(-1, 1)
y_gb = gb_data['Life_Expectancy'].values

X_usa = usa_data['Year'].values.reshape(-1, 1)
y_usa = usa_data['Life_Expectancy'].values

# fitting  linear regression model for Great Britain
model_gb = LinearRegression()
model_gb.fit(X_gb, y_gb)

# fitting linear regression model for USA
model_usa = LinearRegression()
model_usa.fit(X_usa, y_usa)

# predicting  life expectancy for Great Britain and USA in the year 2020
life_expectancy_gb_2020 = model_gb.predict([[2020]])[0]
life_expectancy_usa_2020 = model_usa.predict([[2020]])[0]

# calculating the difference in life expectancy between USA and Great Britain
difference = life_expectancy_usa_2020 - life_expectancy_gb_2020

print(f"Predicted life expectancy for Great Britain in 2020: {life_expectancy_gb_2020:.2f}")
print(f"Predicted life expectancy for USA in 2020: {life_expectancy_usa_2020:.2f}")
print(f"Difference in life expectancy: {difference:.2f} years")

# calculating the number of years for Great Britain to catch up with USA
rate_of_change_gb = model_gb.coef_[0]
rate_of_change_usa = model_usa.coef_[0]

years_to_catch_up = difference / (rate_of_change_usa - rate_of_change_gb)
print(f"Number of years for Great Britain to catch up with USA: {years_to_catch_up:.2f} years")
# Out:
# Predicted life expectancy for Great Britain in 2020: 82.13
# Predicted life expectancy for USA in 2020: 79.64
# Difference in life expectancy: -2.48 years
# Number of years for Great Britain to catch up with USA: 42.20 years

# %% [markdown]
# Observation: I use linear regression module to find out the prediction that Great Britain would take around 42 years to catch up with USA.
